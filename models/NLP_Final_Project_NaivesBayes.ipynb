# %%
from google.colab import drive
import pandas as pd
drive.mount('/content/drive')
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import classification_report, f1_score, confusion_matrix
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
train_df = pd.read_csv('/content/drive/MyDrive/NLP_Final_Project/train_clean.csv')
test_df  = pd.read_csv('/content/drive/MyDrive/NLP_Final_Project/test_clean.csv')

# %%
train_df.head()
# Out:
#                                                 text  label  \
# 0  − Scope 3: Optional scope that includes indire...      1
# 1  The Group is not aware of any noise pollution ...      0
# 2  Global climate change could exacerbate certain...      0
# 3  Setting an investment horizon is part and parc...      0
# 4  Climate change the physical impacts of climate...      0
#
#                                           text_clean
# 0  - Scope 3: Optional scope that includes indire...
# 1  The Group is not aware of any noise pollution ...
# 2  Global climate change could exacerbate certain...
# 3  Setting an investment horizon is part and parc...
# 4  Climate change the physical impacts of climate...

# %%
test_df.head()
# Out:
#                                                 text  label  \
# 0  Sustainable strategy ‘red lines’ For our susta...      0
# 1  Verizon’s environmental, health and safety man...      1
# 2  In 2019, the Company closed a series of transa...      1
# 3  In December 2020, the AUC approved the Electri...      0
# 4  Finally, there is a reputational risk linked t...      0
#
#                                           text_clean
# 0  Sustainable strategy 'red lines' For our susta...
# 1  Verizon's environmental, health and safety man...
# 2  In 2019, the Company closed a series of transa...
# 3  In December 2020, the AUC approved the Electri...
# 4  Finally, there is a reputational risk linked t...

# %%
train_df = train_df.drop(columns=["text"], errors="ignore")
test_df  = test_df.drop(columns=["text"], errors="ignore")

# %%
train_df = train_df.rename(columns={"text_clean": "text"})
test_df  = test_df.rename(columns={"text_clean": "text"})

# %% [markdown]
# # TF-IDF vectorizer

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(
    max_features=20000,
    ngram_range=(1, 3)
)

X_train = vectorizer.fit_transform(train_df["text"])
X_test  = vectorizer.transform(test_df["text"])

y_train = train_df["label"].values
y_test  = test_df["label"].values

# %%
nb_clf = MultinomialNB(alpha=0.5)
nb_clf.fit(X_train, y_train)

nb_preds = nb_clf.predict(X_test)

# %%
# === NAIVE BAYES ===
print("=== Naive Bayes ===")
print(classification_report(
    y_test, nb_preds, digits=4
))

print("Macro F1:", f1_score(y_test, nb_preds, average='macro'))
print(confusion_matrix(y_test, nb_preds))
# Out:
# === Naive Bayes ===
#               precision    recall  f1-score   support
#
#            0     0.8198    0.8585    0.8387       106
#            1     0.7435    0.8712    0.8023       163
#            2     0.7778    0.2745    0.4058        51
#
#     accuracy                         0.7719       320
#    macro avg     0.7804    0.6681    0.6823       320
# weighted avg     0.7742    0.7719    0.7511       320
#
# Macro F1: 0.6822555552914267
# [[ 91  13   2]
#  [ 19 142   2]
#  [  1  36  14]]
